# %% [markdown]
# <a href="https://colab.research.google.com/github/22wj1a6786-commits/automotive-reliability-pipeline/blob/main/Data_Scraper_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

print("Connecting to Team-BHP...")

url = "https://www.team-bhp.com/forum/motorbikes/208595-hero-xpulse-200-review-10.html"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)

if response.status_code == 200:
    print("Connection Successful! Raw HTML acquired.")
else:
    print("Connection Failed.")
# Out:
# Connecting to Team-BHP...
# Status Code: 403
# Connection Failed.
